# %% [markdown]
# <a href="https://colab.research.google.com/github/pavani-tvs88/functions-from-zero/blob/main/functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Styles of functions

# %%
def simple():pass

# %%
def simple2():
  print("Simple")

# %%
simple2()
# Out:
# Simple

# %% [markdown]
# ### Most useful

# %%
def my_worker(fruit):
  statement = f"My favorite meal is palak panner and {fruit}"
  meals = {"dinner" : statement}
  return meals
meal = my_worker("Red Grape")

# %%
type(meal)
# Out:
# dict

# %%
meal
# Out:
# {'dinner': 'My favorite meal is palak panner and Red Grape'}

# %%
meal.keys()
# Out:
# dict_keys(['dinner'])

# %%
def human(food):
  consume = food["dinner"]
  return consume

# %%
my_meal =  human(meal)

print(f"I want my meal. It will be: {my_meal}")
# Out:
# I want my meal. It will be: My favorite meal is palak panner and Red Grape
