# %% [markdown]
# <a href="https://colab.research.google.com/github/pavani-tvs88/functions-from-zero/blob/main/Statments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Learning Statements

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ### Variables

# %%
variable = 1

# %%
x=1
y=2
x+y
# Out:
# 3

# %% [markdown]
# ### Data Structures

# %%
my_list = [1,2,3]
# Out:
# 2

# %%
my_list[0]
# Out:
# 1

# %%
my_list[1]
# Out:
# 2

# %% [markdown]
# ###Dictionary

# %%
my_dict = {1: "one", 2: "two"}
type(my_dict)
# Out:
# dict

# %%
my_dict.keys()
# Out:
# dict_keys([1, 2])

# %%
my_dict.values()
# Out:
# dict_values(['one', 'two'])

# %% [markdown]
# ###Loops

# %%
for key, value in my_dict.items():
  print(f"This is my key: {key}")
  print(f"This is my Value: {value}")
# Out:
# This is my key: 1
# This is my Value: one
# This is my key: 2
# This is my Value: two

# %%
for items in my_list:
  print(f"This is the value in the list: {items}")
# Out:
# This is the value in the list: 1
# This is the value in the list: 2
# This is the value in the list: 3
